# %%
import os
import time
import threading
from pymycobot.mycobot280 import MyCobot280
from pymycobot.genre import Angle, Coord

# %%
mc = MyCobot280('/dev/ttyJETCOBOT', 1000000)
mc.thread_lock = True
print("로봇이 연결되었습니다.")
# Out:
# 로봇이 연결되었습니다.

# %%
initial_angles = [0, 0, 0, 0, 0, -50]
speed = 50
print("로봇을 초기 위치로 리셋합니다")
mc.send_angles(initial_angles, speed)
mc.set_gripper_value(100, speed)
time.sleep(1)
print("리셋완료")
# Out:
# 로봇을 초기 위치로 리셋합니다
# 리셋완료

# %%
# 관절 1(베이스)을 30도로 이동
joint_id = Angle.J1.value # 관절 1 (베이스)
angle = 30
speed = 50
print(f"관절 {joint_id}를 {angle}도로 이동합니다.")
mc.send_angle(joint_id, angle, speed)
time.sleep(5) # 움직임이 완료될 때까지 대기
# 관절 1을 다시 0도로 복귀
print(f"관절 {joint_id}를 0도로 복귀합니다.")
mc.send_angle(joint_id, 0, speed)
time.sleep(1) # 움직임이 완료될 때까지 대기
# Out:
# 관절 1를 30도로 이동합니다.
# 관절 1를 0도로 복귀합니다.

# %%
 # 관절 2(베이스)을 30도로 이동
joint_id = Angle.J2.value # 관절 2 (베이스)
angle = -35
speed = 50
print(f"관절 {joint_id}를 {angle}도로 이동합니다.")
mc.send_angle(joint_id, angle, speed)
time.sleep(2) # 움직임이 완료될 때까지 대기
# 관절 1을 다시 0도로 복귀
print(f"관절 {joint_id}를 0도로 복귀합니다.")
mc.send_angle(joint_id, 0, speed)
time.sleep(2) # 움직임이 완료될 때까지 대기
# Out:
# 관절 2를 -35도로 이동합니다.
# 관절 2를 0도로 복귀합니다.

# %%
 # 관절 3(베이스)을 30도로 이동
joint_id = Angle.J3.value # 관절 2 (베이스)
angle = -60
speed = 20

print(f"관절 {joint_id}를 {angle}도로 이동합니다.")
mc.send_angle(joint_id, angle, speed)
time.sleep(1) # 움직임이 완료될 때까지 대기

# waypoint1
print(f"관절 {joint_id}를 0도로 복귀합니다.")
mc.send_angle(joint_id, -50, speed)
time.sleep(0.01) # 움직임이 완료될 때까지 대기

# waypoint2
print(f"관절 {joint_id}를 0도로 복귀합니다.")
mc.send_angle(joint_id, -40, speed)
time.sleep(0.01) # 움직임이 완료될 때까지 대기

# 관절 1을 다시 0도로 복귀
print(f"관절 {joint_id}를 0도로 복귀합니다.")
mc.send_angle(joint_id, -30, speed)
time.sleep(2) # 움직임이 완료될 때까지 대기
# Out:
# 관절 3를 -60도로 이동합니다.
# 관절 3를 0도로 복귀합니다.
# 관절 3를 0도로 복귀합니다.
# 관절 3를 0도로 복귀합니다.

# %%
 # 관절 4(베이스)을 30도로 이동
joint_id = Angle.J4.value # 관절 2 (베이스)
angle = 0
speed = 50
print(f"관절 {joint_id}를 {angle}도로 이동합니다.")
mc.send_angle(joint_id, angle, speed)
time.sleep(2) # 움직임이 완료될 때까지 대기
# 관절 1을 다시 0도로 복귀
print(f"관절 {joint_id}를 0도로 복귀합니다.")
mc.send_angle(joint_id, -30, speed)
time.sleep(2) # 움직임이 완료될 때까지 대기
# Out:
# 관절 4를 0도로 이동합니다.
# 관절 4를 0도로 복귀합니다.

# %%
 # 관절 5(베이스)을 30도로 이동
joint_id = Angle.J5.value # 관절 2 (베이스)
angle = -30
speed = 50
print(f"관절 {joint_id}를 {angle}도로 이동합니다.")
mc.send_angle(joint_id, angle, speed)
time.sleep(5) # 움직임이 완료될 때까지 대기
# 관절 1을 다시 0도로 복귀
print(f"관절 {joint_id}를 0도로 복귀합니다.")
mc.send_angle(joint_id, 0, speed)
time.sleep(2) # 움직임이 완료될 때까지 대기
# Out:
# 관절 5를 -30도로 이동합니다.
# 관절 5를 0도로 복귀합니다.

# %%
 # 관절 6(베이스)을 30도로 이동
joint_id = Angle.J6.value # 관절 2 (베이스)
angle = -20
speed = 50
print(f"관절 {joint_id}를 {angle}도로 이동합니다.")
mc.send_angle(joint_id, angle, speed)
time.sleep(5) # 움직임이 완료될 때까지 대기
# 관절 1을 다시 0도로 복귀
print(f"관절 {joint_id}를 0도로 복귀합니다.")
mc.send_angle(joint_id, -50, speed)
time.sleep(2) # 움직임이 완료될 때까지 대기
# Out:
# 관절 6를 -20도로 이동합니다.
# 관절 6를 0도로 복귀합니다.
